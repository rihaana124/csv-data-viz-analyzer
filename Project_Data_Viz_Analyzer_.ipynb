# %% [markdown]
# <a href="https://colab.research.google.com/github/rihaana124/csv-data-viz-analyzer/blob/main/Project_Data_Viz_Analyzer_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
#Mount google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#function to read and parse CSV files
def read_csv(file_path):
    try:
        data = pd.read_csv(file_path)
        return data
    except Exception as e:
        print("Error:", e)
        return None

#function to perform basic statistical analysis
def perform_analysis(data):
    analysis_results = {}
    analysis_results['mean'] = data.mean(numeric_only=True)
    analysis_results['median'] = data.median(numeric_only=True)
    analysis_results['mode'] = data.mode().iloc[0] # For multiple modes
    analysis_results['standard_deviation'] = data.std(numeric_only=True)
    #add more statistical measures as needed
    return analysis_results

def generate_plots(data):
  #plots
    sns.histplot(data, bins=20)
    plt.title('Histogram of Data')
    plt.show()

    sns.scatterplot(x='Customer Satisfaction Score (1-10)', y='Region', data=data)  # Specify x and y columns for the scatter plot
    plt.title('Scatter Plot')
    plt.show()

    sns.lineplot(x='Customer Satisfaction Score (1-10)', y='Region', data=data)
    plt.title('Line Plot')
    plt.show()

#function to answer questions about the data
def answer_questions(data):
    #questions
    print("Number of rows:", len(data))
    print("Number of columns:", len(data.columns))
    #Add more questions and answers as needed

#Main function
def main():
    while True:
        file_path = input("Enter the path to the CSV file (or type 'exit' to quit): ").strip()
        if file_path.lower() == 'exit':
            print("Exiting the program...")
            break
        try:
            data = read_csv(file_path)
            if data is not None:
                analysis_results = perform_analysis(data)
                print("Statistical Analysis:")
                for stat, result in analysis_results.items():
                    print(stat.capitalize() + ":", result)

                generate_plots(data)
                answer_questions(data)
                break  # Exit the loop after successful execution
        except Exception as e:
            print("Error:", e)
            print("Please make sure the file path is correct and the file is in CSV format.")
if __name__=='__main__':
  main()
# Out:
# Enter the path to the CSV file (or type 'exit' to quit): /content/drive/MyDrive/Colab Notebooks/Netflix Engagement Dataset.csv
# Statistical Analysis:
# Mean: Customer ID                           1750.500000
# Subscription Length (Months)            30.538000
# Customer Satisfaction Score (1-10)       6.929714
# Daily Watch Time (Hours)                 3.509451
# Engagement Rate (1-10)                   6.954286
# Support Queries Logged                   5.023714
# Age                                     43.868286
# Monthly Income ($)                    5491.886857
# Number of Profiles Created               3.018857
# dtype: float64
# Median: Customer ID                           1750.50
# Subscription Length (Months)            31.00
# Customer Satisfaction Score (1-10)       8.00
# Daily Watch Time (Hours)                 3.51
# Engagement Rate (1-10)                   8.00
# Support Queries Logged                   5.00
# Age                                     44.00
# ...
